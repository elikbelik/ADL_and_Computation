# %% [markdown]
# # Distance from Initialization in Two Layers

# %% [markdown]
# ## Init

# %%
#Autocomplete
# %config Completer.use_jedi = False

# %%
# %matplotlib inline
# %time

import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# Wall time: 0 ns

# %%
os.environ['KERAS_BACKEND'] = "tensorflow"

import keras
from keras import models, layers, activations, initializers
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Input
from keras.initializers import glorot_normal, RandomNormal
from keras.callbacks import EarlyStopping
from keras.engine import base_layer
from keras.utils import control_flow_util
import tensorflow as tf
from tqdm.notebook import tqdm
from tqdm.keras import TqdmCallback

# %%
# adding project's file
import metric as M
from visualization import visualize

# %% [markdown]
# ## I/O

# %%
# Dump
r"""
import pickle

with open(r'C:\Users\elad\work\python_output\random_sketch.pkl', 'wb') as f:
    pickle.dump(result, f)
"""

# Load
r"""
import pickle

with open(r'C:\Users\elad\work\python_output\random_sketch.pkl', 'rb') as f:
    result = pickle.load(f)
"""
# Out:
# "\nimport pickle\n\nwith open(r'C:\\Users\\elad\\work\\python_output\\random_sketch.pkl', 'rb') as f:\n    result = pickle.load(f)\n"

# %% [markdown]
# ## Two-Layers Network that Remembers Distance

# %%
DISTANCE_METRIC = 'distance_from_init'
GRADIENT_METRIC = 'loss_gradient_norm'

# %%
def get_generalization(history, metric='loss'):
    return np.array(history.history['val_' + metric]) - np.array(history.history[metric])

# %%
# This metric will be called twice -
# The first time with real y_true, y_pred and there is nothing to get from it
# The second time, the real value will be in y_true and y_pred will be Zero
def changableMetric (name):
    def fn (y_true, y_pred):
        if tf.size(y_pred) == 1:
            # we multiply by 2 as the metric gets the average of all return values,
            # in our case, the average of 0 and the real value
            return 2 * y_true
        return tf.constant(0, dtype=tf.float32)
    
    fn.__name__ = name
    return fn

# %%
class SimpleNN(Model):
    def __init__(self, input_dim,
                 hidden_layers=None,
                 dist_from_init=None,
                 learning_rate=0.1,
                 last_layer_activation='sigmoid',
                 dropout_rate = None,
                 seed=0,
                 **kwargs):
        super(SimpleNN, self).__init__(**kwargs)
        
        self.distance_from_init = dist_from_init
        self.dropout_rate = dropout_rate
        if dist_from_init is not None:
            self.distance_from_init = tf.constant(dist_from_init, dtype=tf.float32)
        
        if hidden_layers is None:
            hidden_layers = input_dim
            
        self.seq = Sequential()
        self.d1 = Dense(hidden_layers, input_dim=input_dim, activation='relu', use_bias=False,
                        kernel_initializer=RandomNormal(mean=0.0, stddev=1./np.sqrt(input_dim), seed=seed))
        self.d2 = Dense(1, activation=last_layer_activation, use_bias=False,
                        kernel_initializer=RandomNormal(mean=0.0, stddev=1./np.sqrt(hidden_layers), seed=seed+1))

        
        self.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
                    metrics=['accuracy', changableMetric(DISTANCE_METRIC), changableMetric(GRADIENT_METRIC)])
        
        self.init_weights = None
        self.input_dim = input_dim
        self.hidden_layers = hidden_layers
        self.last_layer_activation = last_layer_activation
        
        
        
    def call(self, x, training=None):
        if self.dropout_rate and training==True:
            return self.call_dropout(x, training)
        else:
            return self.call_simple(x, training)
    
    def call_simple(self, x, training):
        x = self.seq(x)
        x = self.d1(x)
        return self.d2(x)
    
    def call_dropout(self, x, training):
        dropout_layer = Dropout(self.dropout_rate)
        x = self.seq(x)
        x = self.d1(x)
        x = dropout_layer(x, training=training)
        x = self.d2(x)
        x = dropout_layer(x, training=training)
        return x
    
    def train_step(self, data):
        # Unpack the data
        X, y = data
        
        with tf.GradientTape() as tape:
            # training=True is only needed if there are layers with different
            # behavior during training versus inference (e.g. Dropout).
            predictions = self(X, training=True)  # Forward pass
            # Compute the loss value
            loss = self.compiled_loss(y, predictions)
            
        # Saves the initial weights
        if self.init_weights is None:
            self.init_weights = []
            for wgt in self.trainable_variables:
                wgt_0 = tf.Variable(wgt, trainable=False)
                wgt_0.assign(wgt)
                self.init_weights.append(wgt_0)

        # Compute gradients
        gradients = tape.gradient(loss, self.trainable_variables)
        g_norm_sqr = 0
        for grad in gradients:
            g_norm_sqr += tf.math.square(tf.norm(grad, ord='fro', axis=(0,1)))
        
        # Update weights
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        # Normalize weights in needed
        total_dist_sqr = 0
        for wgt_t, wgt_0 in zip(self.trainable_variables, self.init_weights):
            diff = wgt_t - wgt_0
            d = tf.norm(diff, ord='fro', axis=(0,1))
            total_dist_sqr += tf.math.square(d)
            if self.distance_from_init is not None:
                ratio = tf.minimum(tf.divide(self.distance_from_init, d), tf.constant(1.0))
                wgt_t.assign(tf.math.scalar_mul(ratio, diff) + wgt_0)

        # Update metrics (includes the metric that tracks the loss)
        self.compiled_metrics.update_state(y, predictions)
        [metric.update_state(tf.math.sqrt(total_dist_sqr), 0) for metric in self.metrics if metric.name == DISTANCE_METRIC]
        [metric.update_state(tf.math.sqrt(g_norm_sqr), 0) for metric in self.metrics if metric.name == GRADIENT_METRIC]
        
        # Return a dict mapping metric names to current value
        return {m.name: m.result() for m in self.metrics}

# %% [markdown]
# ## Radom Sketch Functions

# %%
def random_sketch_vector (vec, k, R_sq=None, seed=None):
    """
    Input:
    vec = the vector to choose from
    k = the number of repetitions
    R_sq = a bound on the norm; if None is given then take the norm itself
    seed = for controlling randomization
    """
    if seed is not None:
        np.random.seed(seed)
    if R_sq is None:
        R_sq = np.sum(vec**2)
    idxs = np.random.choice(np.arange(vec.size), p=np.reshape(vec**2/R_sq,[-1]), size=(k))
    res = np.zeros(vec.shape)
    for i in idxs:
        j = np.unravel_index(i,vec.shape)
        if vec[j] != 0:
            res[j] += R_sq / vec[j]
    if k > 0:
        res /= k
    return res

# %%
def random_sketch_matrix_single_column (mat, k, R_sq=None, seed=None):
    if seed is not None:
        np.random.seed(seed)
    if R_sq is None:
        R_sq = np.sum(mat**2)
    norms_sq = np.sum(mat**2, axis=0)
    col = np.random.choice(np.arange(mat.shape[1]), p=norms_sq/R_sq, size=(1))
    res = np.zeros(mat.shape)
    res[:, col] = random_sketch_vector(np.squeeze(mat[:,col]), k).reshape((-1,1)) * R_sq / norms_sq[col]
    return res

# %%
def random_sketch_matrix_several_columns (mat, k, R_sq=None, seed=None):
    if seed is not None:
        np.random.seed(seed)
    if R_sq is None:
        R_sq = np.sum(mat**2)
    norms_sq = np.sum(mat**2, axis=0)
    cols = np.random.choice(np.arange(mat.shape[1]), p=norms_sq/R_sq, size=(k))
    res = np.zeros(mat.shape)
    for col in cols:
        res[:, col] += random_sketch_vector(np.squeeze(mat[:,col]), 1) * R_sq / norms_sq[col]
    return res / k

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Verification

# %%
# params
m = 200 # Sample size
d = 10 # Input size
np.random.seed(6) # fix random seed for reproducibility
X = np.random.randint(low=0, high=2, size=(m,d)) * 2 - 1 # sample set in {-1,+1}^d
w_true = np.random.randn(d) / np.sqrt(d)
Y_true = (np.sign(X @ w_true) + 1) // 2
#w_true = np.random.randn(d,d) / d
#u_true = np.random.randn(d) / np.sqrt(d)
#Y_true = (np.sign(np.maximum(0, X @ w_true) @ u_true) + 1) // 2

# Train and Test sets
perm = np.random.permutation(m)
X_train = X[perm[:m//2], :]
X_test = X[perm[m//2:], :]
Y_train = Y_true[perm[:m//2]]
Y_test = Y_true[perm[m//2:]]

# %%
num_epochs = 100
model = SimpleNN(d, learning_rate=0.1,  hidden_layers=50, last_layer_activation=None, dist_from_init=1)
history = model.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs)

visualize(history)
# Out:
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %% [markdown]
# ### Random Sketch

# %%
model.summary()
# Out:
# Model: "simple_nn"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     multiple                  0
#
#  dense (Dense)               multiple                  500
#
#  dense_1 (Dense)             multiple                  50
#
# =================================================================
# Total params: 1,100
# Trainable params: 550
# Non-trainable params: 550
# _________________________________________________________________

# %%
W_trained = model.trainable_variables[0].numpy()
u_trained = model.trainable_variables[1].numpy()

# %%
# Verify parameters
np.concatenate([model.predict(X_test[:5, :]),
np.maximum(0, X_test[:5, :] @ W_trained) @ u_trained], axis=1)
# Out:
# 1/1 [==============================] - 0s 54ms/step
# array([[ 0.07279236,  0.07279229],
#        [-2.25556302, -2.25556285],
#        [ 1.5125432 ,  1.51254326],
#        [ 0.5089184 ,  0.50891841],
#        [-1.28323126, -1.28323132]])

# %%
# %%time

k = 100
res_mean = np.zeros(k)
res_var = np.zeros(k)
real_res = model.predict(X_test)
for i in range(k):
    W_rs = random_sketch_matrix_single_column(W_trained, i+1, seed=i)
    rand_res = np.maximum(0, X_test @ W_rs) @ u_trained
    diff = real_res - rand_res
    res_mean[i] = np.mean(diff)
    res_var[i] = np.var(diff)
# Out:
# 4/4 [==============================] - 0s 1000us/step
# Wall time: 75.9 ms

# %%
_, axs = plt.subplots(1, 2, figsize=(15,4))
axs[0].plot(res_mean)
axs[0].set_title('mean value')
axs[1].plot(res_var)
axs[1].set_title('variance')
# Out:
# Text(0.5, 1.0, 'variance')

# %%
# %%time

k = 100
res_mean = np.zeros(k)
res_var = np.zeros(k)
real_res = model.predict(X_test)
for i in range(k):
    W_rs = random_sketch_matrix_several_columns(W_trained, i+1, seed=i)
    rand_res = np.maximum(0, X_test @ W_rs) @ u_trained
    diff = real_res - rand_res
    res_mean[i] = np.mean(diff)
    res_var[i] = np.var(diff)
    
_, axs = plt.subplots(1, 2, figsize=(15,4))
axs[0].plot(res_mean)
axs[0].set_title('mean value')
axs[1].plot(res_var)
axs[1].set_title('variance')
# Out:
# 4/4 [==============================] - 0s 2ms/step
# Wall time: 434 ms
# Text(0.5, 1.0, 'variance')

# %% [markdown]
# ### Dropout

# %%
num_epochs = 100
num_hidden = 100

# %%
# Without Dropout
model = SimpleNN(d, learning_rate=0.1,  hidden_layers=num_hidden, dist_from_init=1)
history = model.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs)

visualize(history)
# Out:
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %%
# With Dropout
dropout_rate = 0.2
model_do = SimpleNN(d, learning_rate=0.1,  hidden_layers=num_hidden,
                    dist_from_init=1, dropout_rate=dropout_rate)
history_do = model_do.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs, callbacks=[TqdmCallback(verbose=0)])
visualize(history_do)
# Out:
# 0epoch [00:00, ?epoch/s]
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %% [markdown]
# ## ADL Dropout

# %% [markdown]
# Let $w\in\mathbb{R}^{n}$.
# We want to randomly pick $\tilde{w}$ such that
# $$
# \tilde{w}_i =
# \begin{cases}
# \frac{w_i}{p_i}, & w.p. \; p_i=\frac{w_i^2}{\|w\|^2} \\
# 0, & otherwise
# \end{cases}.
# $$
#
# Instead, we will use a bit different approach, for which $\tilde{w}_i = \frac{w_i}{p_i} \tilde{b}_i$ where $ \tilde{b}_i \sim Ber(p_i)$.
# The difference is that we add an independence assumption between the elements.
#
# Now, let $\hat{w}$ be an average of $k$ independence values of $\tilde{w}$.
# That is, $\hat{w}_i = \frac{w_i}{p_i} \hat{b}_i$ where $\hat{b} \sim Bin(k, p_i)$.
#
# It could be further approximated using normal distribution, but luckily, tensorflow knows how to distribute separately for each weight.

# %% [markdown]
# #### Debug ADL Dropout

# %%
def debug_adl(n, k, out_size=5):
    seed = 0
    inputs = tf.convert_to_tensor(X_test[:out_size, :n], dtype=tf.float32)

    w = tf.random.stateless_normal((n,n), (seed,seed), mean=0.0, stddev=1./np.sqrt(n))

    weights_sq = tf.math.square(w)
    norm_frobenious_sq = tf.math.reduce_sum(weights_sq)
    probs = weights_sq / norm_frobenious_sq
    mask = tf.random.stateless_binomial(shape=w.shape, seed=(seed+1, seed+1), counts=[k], probs=probs)

    normalized_weights = tf.math.divide(tf.cast(mask, dtype=w.dtype), w) * norm_frobenious_sq
    if k > 0:
        normalized_weights /= k
    res = tf.matmul(inputs, normalized_weights)
    
    return (w, inputs, res)

# %%
n = 2
k = 100
res_mean = np.zeros(k)
res_var = np.zeros(k)

real_w, inputs, _ = debug_adl(n, 0, out_size=5)
real_res = tf.matmul(inputs, real_w)

for i in range(k):
    _, _, rand_res = debug_adl(n, i, out_size=5)
    diff = (real_res - rand_res).numpy()
    res_mean[i] = np.mean(diff)
    res_var[i] = np.var(diff)
    
_, axs = plt.subplots(1, 2, figsize=(15,4))
axs[0].plot(res_mean)
axs[0].set_title('mean value')
axs[1].plot(res_var)
axs[1].set_title('variance')
# Out:
# Text(0.5, 1.0, 'variance')

# %%
k = 1000
seed = 0
inputs = tf.convert_to_tensor(X_train[:5, :n], dtype=tf.float32)
y_outputs = tf.convert_to_tensor(Y_train[:5], dtype=tf.float32)
w = tf.Variable(tf.random.stateless_normal([n,1], (seed,seed), mean=0.0, stddev=1./np.sqrt(n)))
weights_sq = tf.math.square(w)
norm_frobenious_sq = tf.math.reduce_sum(weights_sq)
probs = weights_sq / norm_frobenious_sq
mask = tf.random.stateless_binomial(shape=w.shape, seed=(seed+1, seed+1), counts=[k], probs=probs)

w, mask
# Out:
# (<tf.Variable 'Variable:0' shape=(2, 1) dtype=float32, numpy=
#  array([[-1.1999842 ],
#         [-0.34038472]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 1), dtype=int32, numpy=
#  array([[922],
#         [ 73]])>)

# %%
with tf.GradientTape() as tape:    
    #with tape.stop_recording():
    if 1:
        weights_sq = tf.math.square(w)
        norm_frobenious_sq = tf.math.reduce_sum(weights_sq)
        probs = weights_sq / norm_frobenious_sq
    
    mask = tf.random.stateless_binomial(shape=w.shape, seed=(seed+1, seed+1), counts=[k], probs=probs)
    masked_weights = w * tf.cast(mask, dtype=w.dtype)
    
    normalized_weights = tf.math.divide(masked_weights, tf.stop_gradient(probs))
    if k > 0:
        normalized_weights /= k
    predictions = tf.matmul(inputs, normalized_weights)

    #loss = model.compiled_loss(y_outputs, predictions)
    loss = tf.reduce_sum(predictions) # TODO - should be removed and retutrn the previous line
    
# Compute gradients
[gradients] = tape.gradient(loss, [w])

# Update weights
#model.optimizer.apply_gradients(zip([gradients], [w]))

predictions, gradients
# Out:
# (<tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#  array([[ 1.529074  ],
#         [-1.529074  ],
#         [-0.86174005],
#         [ 0.86174005],
#         [ 0.86174005]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
#  array([[-0.9961858],
#         [ 0.9802643]], dtype=float32)>)

# %%
with tf.GradientTape() as tape:    
    with tape.stop_recording():
        weights_sq = tf.math.square(w)
        norm_frobenious_sq = tf.math.reduce_sum(weights_sq)
        probs = weights_sq / norm_frobenious_sq
    
    mask = tf.random.stateless_binomial(shape=w.shape, seed=(seed+1, seed+1), counts=[k], probs=probs)

    normalized_weights = tf.math.divide(tf.cast(mask, dtype=w.dtype), w) * norm_frobenious_sq
    if k > 0:
        normalized_weights /= k
    predictions = tf.matmul(inputs, normalized_weights)

    #loss = model.compiled_loss(y_outputs, predictions)
    loss = tf.reduce_sum(predictions) # TODO - should be removed and retutrn the previous line
    
# Compute gradients
[gradients] = tape.gradient(loss, [w])

# Update weights
#model.optimizer.apply_gradients(zip([gradients], [w]))

predictions, gradients
# Out:
# (<tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#  array([[ 1.529074 ],
#         [-1.529074 ],
#         [-0.8617401],
#         [ 0.8617401],
#         [ 0.8617401]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
#  array([[ 0.9961856 ],
#         [-0.98026425]], dtype=float32)>)

# %%
# Compare to the regular case

with tf.GradientTape() as tape:
    predictions = tf.matmul(inputs, w)
    #loss = model.compiled_loss(y_outputs, predictions)
    loss = tf.reduce_sum(predictions) # TODO - should be removed and retutrn the previous line
    
[gradients] = tape.gradient(loss, [w])
#model.optimizer.apply_gradients(zip([gradients], [w]))

predictions, gradients
# Out:
# (<tf.Tensor: shape=(5, 1), dtype=float32, numpy=
#  array([[ 1.5403689],
#         [-1.5403689],
#         [-0.8595995],
#         [ 0.8595995],
#         [ 0.8595995]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 1), dtype=float32, numpy=
#  array([[-1.],
#         [ 1.]], dtype=float32)>)

# %% [markdown]
# #### Model Implementation

# %%
class ADLDropout(base_layer.BaseRandomLayer):
    """Applies Dropout in ADL sense:
    This layer randomly sets input units to 0 with a frequency of `rate=1 - wi\R*k`
    at each step during training time, which helps prevent overfitting.
    Inputs not set to 0 are scaled up by 1/(1 - rate) such that the sum over
    all inputs is unchanged.

    Note that the Dropout layer only applies when `training` is set to True.

    Args:
    Note that both "k", "rate" and "var" arguments affects on each other, therefore you might want to choose
    only one argument of all.
    k:          The number of repetitions of the random skethches. Can be also contolled by "rate" and "var".
    rate:       Should be somewhat the argument "rate" of dropout: Should represent the probability for
                each element to be chosen. In practice k = rate * size_of_tensor. Overrides "k".
    var:        Bound the variance from the non random case. In practice, k = norm(w)^2 * norm(input)^2 / var.
                Overrides "k" and "rate".
    max_radius: The maximal distance allowed.
    seed:       A seed for the randomization.
    from_init:  Boolean. If true, checks the distance from the initialization, otherwise, uses the distance
                from the origin.
    """

    def __init__(self, width,
                 k=1,
                 activation=None,
                 kernel_initializer='glorot_uniform',
                 bias_initializer='zeros',
                 seed=None,
                 max_radius=None,
                 from_init=False,
                 rate=None,
                 var=None,
                 **kwargs):
        
        super(ADLDropout, self).__init__(seed=seed, **kwargs)
        
        self.width = width
        self.k = k
        self.seed = seed
        if seed is None:
            self.seed = np.random.randint(100)
        self.activation = activations.get(activation)
        self.kernel_initializer = initializers.get(kernel_initializer)
        self.bias_initializer = initializers.get(bias_initializer)
        self.max_radius = max_radius
        self.max_radius_sq = None
        self.from_init = from_init
        self.init_weights = None
        self.rate = rate
        self.num_elements = None
        self.var = var
        self.non_zero_elements_percentage = -1

        
    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.width),
            initializer=self.kernel_initializer, trainable=True)

        self.mask = self.add_weight(shape=(input_shape[-1], self.width),
            initializer="zero", trainable=False)
        
        self.init_weights = tf.Variable(self.w, trainable=False)
        self.init_weights.assign(self.w)
        self.num_elements = tf.cast(tf.math.reduce_prod(self.w.shape), self.w.dtype)
        
        if self.var is not None:
            self.k = np.round(input_shape[-1] * self.width / self.var)
        else:
            if self.rate is not None:
                self.k = np.round(input_shape[-1] * self.width * self.rate)

    def get_non_zero_elements_percentage(self):
        return tf.reduce_mean(tf.cast(self.mask>0, tf.float32))
    
    
    def call(self, inputs, training=None):
        res = None
        inputs = tf.cast(inputs, dtype=self.w.dtype)
        
        if training == True:
            if self.from_init == True:
                res = self.call_dropout_from_init(inputs)
            else:
                res = self.call_dropout_from_origin(inputs)
            self.non_zero_elements_percentage = self.get_non_zero_elements_percentage()
        else: # Not in training
            res = tf.matmul(inputs, self.w) # in case of bias add self.b
            
        if self.activation is not None:
            return self.activation(res)
        else:
            return res

        
    def call_dropout_from_origin(self, inputs):
        weights_sq = tf.math.square(self.w)
        if self.max_radius is None:
            self.max_radius_sq = tf.math.reduce_sum(weights_sq)
        else:
            self.max_radius_sq = self.max_radius * self.max_radius

        probs = tf.minimum(weights_sq / self.max_radius_sq, 1) / 2 + 1 / self.num_elements / 2
        self.mask = tf.cast(tf.random.stateless_binomial(shape=self.w.shape,
                                                         seed=(self.seed, self.seed+1),
                                                         counts=[self.k],
                                                         probs=probs), dtype=self.w.dtype)
        self.seed += 2

        masked_weights = self.w * tf.cast(self.mask, dtype=self.w.dtype)
        normalized_weights = tf.math.divide(masked_weights, tf.stop_gradient(probs))
        if self.k > 0:
            normalized_weights /= self.k
        return tf.matmul(inputs, normalized_weights)
    
    
    def call_dropout_from_init(self, inputs):
        weights_diff = self.w - self.init_weights
        weights_sq = tf.math.square(weights_diff)
        if self.max_radius is None:
            self.max_radius_sq = tf.math.reduce_sum(weights_sq)
        else:
            self.max_radius_sq = self.max_radius * self.max_radius

        probs = tf.ones(self.w.shape, dtype=self.w.dtype)
        if self.max_radius_sq > 0:
            probs = tf.minimum(weights_sq / self.max_radius_sq, 1) / 2 + 1 / self.num_elements / 2
        self.mask = tf.cast(tf.random.stateless_binomial(shape=self.w.shape,
                                                         seed=(self.seed, self.seed+1),
                                                         counts=[self.k],
                                                         probs=probs), dtype=self.w.dtype)
        self.seed += 2

        normalized_mask = tf.math.divide(tf.cast(self.mask, dtype=self.w.dtype), probs)
        if self.k > 0:
            normalized_mask /= self.k
        normalized_weights = self.w * tf.stop_gradient(normalized_mask) \
                             + tf.stop_gradient(self.init_weights * (1-normalized_mask))
        
        return tf.matmul(inputs, normalized_weights)
        #masked_weights = weights_diff * tf.cast(self.mask, dtype=self.w.dtype)
        #normalized_weights = tf.math.divide(masked_weights, tf.stop_gradient(probs))
        #if self.k > 0:
        #    normalized_weights /= self.k
        #return tf.matmul(inputs, normalized_weights + self.init_weights)

# %%
class ADLModel(SimpleNN):
    def __init__(self, input_dim, k=1, var=None, from_init=False, **kwargs):
        super(ADLModel, self).__init__(input_dim, **kwargs)
                    
        self.seq = Sequential()
        self.d1 = ADLDropout(self.hidden_layers,
                             input_dim=input_dim,
                             activation=keras.activations.relu,
                             max_radius=self.distance_from_init, k=k,
                             from_init=from_init, var=var,
                             kernel_initializer=RandomNormal(mean=0.0, stddev=1./np.sqrt(input_dim)))
        self.d2 = ADLDropout(1, activation=self.last_layer_activation,
                             max_radius=self.distance_from_init, k=k,
                             from_init=from_init, var=var,
                             kernel_initializer=RandomNormal(mean=0.0, stddev=1./np.sqrt(self.hidden_layers)))

        
    def call(self, x, training=None):
        x = self.seq(x)
        x = self.d1(x)
        return self.d2(x)

# %%
# With ADL Dropout
k = 1000
model_adl = ADLModel(d, learning_rate=0.1,  k=k, hidden_layers=num_hidden, seed=0)
history_adl = model_adl.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs, callbacks=[TqdmCallback(verbose=0)])
visualize(history_adl)
# Out:
# 0epoch [00:00, ?epoch/s]
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %%
# With ADL Dropout
k = 50
model_adl = ADLModel(d, learning_rate=0.01,  k=k, hidden_layers=num_hidden, seed=0)
history_adl = model_adl.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs, callbacks=[TqdmCallback(verbose=0)])
visualize(history_adl)
# Out:
# 0epoch [00:00, ?epoch/s]
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %%
# With ADL Dropout From Init
k = 1000
model_adl = ADLModel(d, learning_rate=0.1,  k=k, hidden_layers=num_hidden, seed=0, from_init=True)
history_adl = model_adl.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs, callbacks=[TqdmCallback(verbose=0)])
visualize(history_adl)
# Out:
# 0epoch [00:00, ?epoch/s]
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %%
# With ADL Dropout From Init
k = 50
model_adl = ADLModel(d, learning_rate=0.1,  k=k, hidden_layers=num_hidden, seed=0, from_init=True)
history_adl = model_adl.fit(x=X_train, y=Y_train, validation_data=(X_test,Y_test),
                            batch_size = 20, verbose=0, epochs=num_epochs, callbacks=[TqdmCallback(verbose=0)])
visualize(history_adl)
# Out:
# 0epoch [00:00, ?epoch/s]
# (<Figure size 1080x288 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'accuracy'}>,
#         <AxesSubplot:title={'center':'distance_from_init'}>,
#         <AxesSubplot:title={'center':'loss_gradient_norm'}>], dtype=object))

# %% [markdown]
# ## Performance Testing

# %%
(X_train_mnist, y_train_mnist), (X_test_mnist, y_test_mnist) = tf.keras.datasets.mnist.load_data()

# %%
dropout_rate = np.arange(0, 1, .1)
epochs = 15

# %%
# Simple Case

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(300, activation="relu", use_bias=False))
model.add(keras.layers.Dense(300, activation="relu", use_bias=False))
model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

optimizer = keras.optimizers.Nadam(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
res_loss, res_acc = model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1553 - accuracy: 0.9717

# %%
# Regular Dropout

res_dropout = np.zeros((2,dropout_rate.size))

for i, r in tqdm(enumerate(dropout_rate)):
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))
    model.add(keras.layers.Dropout(r))
    model.add(keras.layers.Dense(300, activation="relu", use_bias=False))
    model.add(keras.layers.Dropout(r))
    model.add(keras.layers.Dense(300, activation="relu", use_bias=False))
    model.add(keras.layers.Dropout(r))
    model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

    optimizer = keras.optimizers.SGD(learning_rate=0.001)
    model.compile(loss="sparse_categorical_crossentropy", 
                  optimizer=optimizer, metrics=["accuracy"])
    model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
              verbose=0, callbacks=[TqdmCallback(verbose=0)])
    res_dropout[0,i], res_dropout[1,i] = model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0it [00:00, ?it/s]
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2197 - accuracy: 0.9610
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1116 - accuracy: 0.9665
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1470 - accuracy: 0.9553
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1819 - accuracy: 0.9477
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.2855 - accuracy: 0.9325
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.5592 - accuracy: 0.8960
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.9580 - accuracy: 0.7872
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 1.8006 - accuracy: 0.2895
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 2.3026 - accuracy: 0.0980
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: nan - accuracy: 0.0980

# %%
plt.plot(dropout_rate, res_dropout[1,:])

# %%
res_dropout_adl = np.zeros((2,len(dropout_rate)))

for i, r in tqdm(enumerate(dropout_rate)):
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))
    model.add(ADLDropout(300, activation=keras.activations.relu, var=1-r, from_init=False))
    model.add(ADLDropout(300, activation=keras.activations.relu, var=1-r, from_init=False))
    model.add(ADLDropout(10, activation=keras.activations.softmax, var=1-r, from_init=False))

    optimizer = keras.optimizers.SGD(learning_rate=0.001)
    model.compile(loss="sparse_categorical_crossentropy", 
                  optimizer=optimizer, metrics=["accuracy"])
    model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
              verbose=0, callbacks=[TqdmCallback(verbose=0)])
    res_dropout_adl[0,i], res_dropout_adl[1,i] = model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0it [00:00, ?it/s]
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 12.3754 - accuracy: 0.2875
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 9.3696 - accuracy: 0.2813
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 9.3916 - accuracy: 0.3422
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 9.0390 - accuracy: 0.3784
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 5.5595 - accuracy: 0.3835
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 2.7857 - accuracy: 0.6234
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 3.2607 - accuracy: 0.6342
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 1.5988 - accuracy: 0.7967
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 1.4145 - accuracy: 0.8182
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3951 - accuracy: 0.9291

# %%
plt.plot(dropout_rate, res_dropout_adl[1,:])

# %%
res_dropout_adl_diff = np.zeros((2,len(dropout_rate)))

for i, r in tqdm(enumerate(dropout_rate)):
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=(28, 28)))
    model.add(ADLDropout(300, activation=keras.activations.relu, var=1-r, from_init=True))
    model.add(ADLDropout(300, activation=keras.activations.relu, var=1-r, from_init=True))
    model.add(ADLDropout(10, activation=keras.activations.softmax, var=1-r, from_init=True))

    optimizer = keras.optimizers.SGD(learning_rate=0.001)
    model.compile(loss="sparse_categorical_crossentropy", 
                  optimizer=optimizer, metrics=["accuracy"])
    model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
              verbose=0, callbacks=[TqdmCallback(verbose=0)])
    res_dropout_adl_diff[0,i], res_dropout_adl_diff[1,i] = model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0it [00:00, ?it/s]
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 1.1623 - accuracy: 0.8891
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 1.2517 - accuracy: 0.8751
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 1ms/step - loss: 0.7918 - accuracy: 0.9169
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5309 - accuracy: 0.9300
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5610 - accuracy: 0.9337
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4497 - accuracy: 0.9392
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4796 - accuracy: 0.9302
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3992 - accuracy: 0.9451
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3028 - accuracy: 0.9537
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2867 - accuracy: 0.9550

# %%
plt.plot(dropout_rate, res_dropout_adl[1,::-1], dropout_rate,
         res_dropout_adl_diff[1,::-1],dropout_rate, res_dropout[1,:],
        [0,1],[res_acc, res_acc])
plt.legend(['ADL from Origin','ADL from Init', 'Dropout','Nothing'])
plt.xlabel('rate')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')

# %%
plt.plot(#dropout_rate[:7], res_dropout_adl[0,:2:-1],
         dropout_rate[:7], res_dropout_adl_diff[0,:2:-1],
         dropout_rate[:7], res_dropout[0,:7],
        [0,.6],[res_loss, res_loss])
plt.legend(['ADL from Init', 'Dropout','Nothing'])
plt.xlabel('rate')
plt.ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### Comparing to Original Paper

# %% [markdown]
# The paper is called "Dropout:  A Simple Way to Prevent Neural Networks fromOverfitting" and can be found [here](moz-extension://cb5ce5cd-fad9-42cf-b14d-a6c3819355df/enhanced-reader.html?openApp&pdf=https%3A%2F%2Fjmlr.org%2Fpapers%2Fvolume15%2Fsrivastava14a%2Fsrivastava14a.pdf).
# Code is [here](http://www.cs.toronto.edu/~nitish/dropout/).

# %%
epochs = 50

# %%
# Original Model

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_orig = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2263 - accuracy: 0.9685
# [0.22630004584789276, 0.968500018119812]

# %%
# Dropout Model

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_dropout = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1400 - accuracy: 0.9700
# [0.14003480970859528, 0.9700000286102295]

# %%
# ADL Dropout Model From Init

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", rate=0.8, from_init=True))
model.add(ADLDropout(800, activation="relu", rate=0.5, from_init=True))
model.add(ADLDropout(10, activation="softmax", rate=0.5, from_init=True))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_adl_init = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 4.4607 - accuracy: 0.8110
# [4.460673809051514, 0.8109999895095825]

# %%
# ADL Dropout Model From Orig

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", rate=0.8, from_init=False))
model.add(ADLDropout(800, activation="relu", rate=0.5, from_init=False))
model.add(ADLDropout(10, activation="softmax", rate=0.5, from_init=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_adl_orig = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 18.4103 - accuracy: 0.2867
# [18.410274505615234, 0.2867000102996826]

# %%
f, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(history_orig.epoch[1:], history_orig.history['loss'][1:], label='no dropout')
axs[0].plot(history_dropout.epoch[1:], history_dropout.history['loss'][1:], label='dropout')
axs[0].plot(history_adl_init.epoch[1:], history_adl_init.history['loss'][1:], label='ADL from init')
axs[0].plot(history_adl_orig.epoch[1:], history_adl_orig.history['loss'][1:], label='ADL from orig')
axs[0].set_xlabel('epochs')
axs[0].set_ylabel('loss')
axs[0].legend()


axs[1].plot(history_orig.epoch, history_orig.history['accuracy'], label='no dropout')
axs[1].plot(history_dropout.epoch, history_dropout.history['accuracy'], label='dropout')
axs[1].plot(history_adl_init.epoch, history_adl_init.history['accuracy'], label='ADL from init')
axs[1].plot(history_adl_orig.epoch, history_adl_orig.history['accuracy'], label='ADL from orig')
axs[1].set_xlabel('epochs')
axs[1].set_ylabel('accuracy')
axs[1].legend()

plt.show()

# %%
f, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(history_orig.epoch[1:], history_orig.history['loss'][1:], label='no dropout')
axs[0].plot(history_dropout.epoch[1:], history_dropout.history['loss'][1:], label='dropout')
axs[0].plot(history_adl_init.epoch[1:], history_adl_init.history['loss'][1:], label='ADL from init')
axs[0].plot(history_adl_orig.epoch[1:], history_adl_orig.history['loss'][1:], label='ADL from orig')
axs[0].set_xlabel('epochs')
axs[0].set_ylabel('loss')
axs[0].legend()


axs[1].plot(history_orig.epoch, history_orig.history['accuracy'], label='no dropout')
axs[1].plot(history_dropout.epoch, history_dropout.history['accuracy'], label='dropout')
axs[1].plot(history_adl_init.epoch, history_adl_init.history['accuracy'], label='ADL from init')
axs[1].plot(history_adl_orig.epoch, history_adl_orig.history['accuracy'], label='ADL from orig')
axs[1].set_xlabel('epochs')
axs[1].set_ylabel('accuracy')
axs[1].legend()

plt.show()

# %% [markdown]
# #### Non-Zero Elements Precentage

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", var=1, from_init=True, seed=0))
model.add(ADLDropout(800, activation="relu", var=1, from_init=True, seed=100))
model.add(Dense(10, activation="softmax"))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
model.fit(X_train_mnist, y_train_mnist, epochs=5,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_train_mnist, y_train_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4397 - accuracy: 0.9282
# [0.43974629044532776, 0.9282000064849854]

# %%
# %%time

var_range = np.concatenate((np.arange(.1,1,.1), np.arange(1,10)))
res_per = np.zeros((3,len(var_range)))

inputs = tf.cast(model.layers[0](X_train_mnist), tf.float32)
model.layers[1].from_init = False
model.layers[2].from_init = False

for i,var in enumerate(var_range):
    model.layers[1].k = np.round(28*28*800 / var)
    model.layers[2].k = np.round(800*800 / var)
    predict = model.layers[3](model.layers[2](model.layers[1](inputs, training=True), training=True))
    res_per[0,i] = model.layers[2].non_zero_elements_percentage / 2 + model.layers[1].non_zero_elements_percentage / 2
    res_per[1,i] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, predict))
    res_per[2,i] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, predict))
# Out:
# Wall time: 11.5 s

# %%
v = model.evaluate(X_train_mnist, y_train_mnist)
# Out:
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.4397 - accuracy: 0.9282

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3), constrained_layout=True)
plt.subplot(1,2,1)
plt.plot(res_per[0,:],res_per[1,:],'*')
plt.plot([1],v[0],'^')
plt.xlabel('non zero elements percentage')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(res_per[0,:],res_per[2,:],'*')
plt.plot([1],v[1],'^')
plt.xlabel('non zero elements percentage')
plt.ylabel('accuracy')

plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3), constrained_layout=True)
plt.subplot(1,2,1)
plt.plot(res_per[0,:],res_per[1,:],'*')
plt.plot([1],v[0],'^')
plt.xlabel('non zero elements percentage')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(res_per[0,:],np.log(res_per[1,:]),'*')
plt.plot([1],np.log(v[0]),'^')
plt.xlabel('non zero elements percentage')
plt.ylabel('log loss')

plt.show()

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", var=1, from_init=True, seed=0))
model.add(ADLDropout(800, activation="relu", var=1, from_init=True, seed=100))
model.add(ADLDropout(10, activation="softmax", var=1, from_init=True, seed=503))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
model.fit(X_train_mnist, y_train_mnist, epochs=5,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_train_mnist, y_train_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.2091 - accuracy: 0.8977
# [1.209078073501587, 0.8977000117301941]

# %%
# %%time

var_range = np.concatenate((np.arange(.1,1,.1), np.arange(1,10)))
res_per_lay = np.zeros((3,len(var_range),3))

inputs = tf.cast(model.layers[0](X_train_mnist), tf.float32)
model.layers[1].from_init = False
model.layers[2].from_init = False
model.layers[3].from_init = False

for layer in range(3):
    training = [layer==0, layer==1, layer==2]
    for i,var in enumerate(var_range):
        model.layers[1].k = np.round(28*28*800 / var)
        model.layers[2].k = np.round(800*800 / var)
        model.layers[3].k = np.round(800*10 / var)
        predict = model.layers[3](model.layers[2](model.layers[1](
            inputs, training=training[0]), training=training[1]), training=training[2])
        res_per_lay[0,i,layer] = model.layers[layer+1].non_zero_elements_percentage
        res_per_lay[1,i,layer] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, predict))
        res_per_lay[2,i,layer] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, predict))
# Out:
# Wall time: 30.2 s

# %%
v = model.evaluate(X_train_mnist, y_train_mnist)
# Out:
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.2091 - accuracy: 0.8977

# %%
fig, axes = plt.subplots(3, 2, figsize=(8,10), constrained_layout=True)

for i in range(3):
    plt.subplot(3,2,2*i+1)
    plt.plot(res_per_lay[0,:,i],res_per_lay[1,:,i],'*')
    plt.plot([1],v[0],'^')
    plt.xlabel('non zero elements percentage')
    plt.ylabel('loss')
    plt.title('layer=%d'%(i+1))

    plt.subplot(3,2,2*i+2)
    plt.plot(res_per_lay[0,:,i],res_per_lay[2,:,i],'*')
    plt.plot([1],v[1],'^')
    plt.xlabel('non zero elements percentage')
    plt.ylabel('accuracy')
    plt.title('layer=%d'%(i+1))

plt.show()

# %% [markdown]
# What if we will use a simple pruning?

# %%
# %%time

percentile = np.arange(100,0,-10)
res_perc = np.zeros((3,len(percentile)))

for i,p in enumerate(percentile):
    w1 = model.layers[1].w.numpy()
    w2 = model.layers[2].w.numpy()
    w3 = model.layers[3].w.numpy()
    w1[np.abs(w1) < np.percentile(np.abs(w1), p)] = 0
    w2[np.abs(w2) < np.percentile(np.abs(w2), p)] = 0
    w3[np.abs(w3) < np.percentile(np.abs(w3), p)] = 0
    pred = keras.activations.softmax(tf.convert_to_tensor(
        np.maximum(0, np.maximum(0, inputs @ w1) @ w2) @ w3))
    res_perc[0,i] = p
    res_perc[1,i] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, pred))
    res_perc[2,i] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, pred))

# %%
# %%time

k_ratios = [0.05, .1, .2, .5, 1, 2, 3, 4, 10]

res_perc_rand = np.zeros((3,len(k_ratios)))
w1 = model.layers[1].w.numpy()
w2 = model.layers[2].w.numpy()
w3 = model.layers[3].w.numpy()

for i,k in enumerate(k_ratios):
    k1 = int(w1.size * k)
    k2 = int(w2.size * k)
    k3 = int(w3.size * k)
    w1_r = random_sketch_vector(w1, k1)
    w2_r = random_sketch_vector(w2, k2)
    w3_r = random_sketch_vector(w3, k3)
    pred = keras.activations.softmax(tf.convert_to_tensor(
        np.maximum(0, np.maximum(0, inputs @ w1_r) @ w2_r) @ w3_r))
    res_perc_rand[0,i] = (np.sum(w1_r == 0) + np.sum(w2_r == 0) + np.sum(w3_r == 0)) \
                    * 100 / (w1.size + w2.size + w3.size)
    res_perc_rand[1,i] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, pred))
    res_perc_rand[2,i] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, pred))
# Out:
# Wall time: 2min 46s

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3), constrained_layout=True)
plt.subplot(1,2,1)
plt.plot(res_perc[0,:],res_perc[1,:],'*')
plt.plot(res_perc_rand[0,:],res_perc_rand[1,:],'^')
plt.legend(['naive prune', 'adl'])
plt.xlabel('percentage of zero elements')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(res_perc[0,:],res_perc[2,:],'*')
plt.plot(res_perc_rand[0,:],res_perc_rand[2,:],'^')
plt.legend(['naive prune', 'adl'])
plt.xlabel('percentage of zero elements')
plt.ylabel('accuracy')

plt.show()

# %% [markdown]
# ### Smooth Functions

# %%
epochs = 50

# %%
# Original Model

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_orig = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2263 - accuracy: 0.9685
# [0.22630004584789276, 0.968500018119812]

# %%
# Dropout Model

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(keras.layers.Dropout(0.2))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(800, activation="relu", use_bias=False))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(10, activation="softmax", use_bias=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_dropout = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1400 - accuracy: 0.9700
# [0.14003480970859528, 0.9700000286102295]

# %%
# ADL Dropout Model From Init

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", rate=0.8, from_init=True))
model.add(ADLDropout(800, activation="relu", rate=0.5, from_init=True))
model.add(ADLDropout(10, activation="softmax", rate=0.5, from_init=True))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_adl_init = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 4.4607 - accuracy: 0.8110
# [4.460673809051514, 0.8109999895095825]

# %%
# ADL Dropout Model From Orig

model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=(28, 28)))
model.add(ADLDropout(800, activation="relu", rate=0.8, from_init=False))
model.add(ADLDropout(800, activation="relu", rate=0.5, from_init=False))
model.add(ADLDropout(10, activation="softmax", rate=0.5, from_init=False))

optimizer = keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer=optimizer, metrics=["accuracy"])
history_adl_orig = model.fit(X_train_mnist, y_train_mnist, epochs=epochs,
          verbose=0, callbacks=[TqdmCallback(verbose=0)])
model.evaluate(X_test_mnist, y_test_mnist)
# Out:
# 0epoch [00:00, ?epoch/s]
# 313/313 [==============================] - 1s 3ms/step - loss: 18.4103 - accuracy: 0.2867
# [18.410274505615234, 0.2867000102996826]

# %%
f, axs = plt.subplots(1, 2, figsize=(15,5))
axs[0].plot(history_orig.epoch[1:], history_orig.history['loss'][1:], label='no dropout')
axs[0].plot(history_dropout.epoch[1:], history_dropout.history['loss'][1:], label='dropout')
axs[0].plot(history_adl_init.epoch[1:], history_adl_init.history['loss'][1:], label='ADL from init')
axs[0].plot(history_adl_orig.epoch[1:], history_adl_orig.history['loss'][1:], label='ADL from orig')
axs[0].set_xlabel('epochs')
axs[0].set_ylabel('loss')
axs[0].legend()


axs[1].plot(history_orig.epoch, history_orig.history['accuracy'], label='no dropout')
axs[1].plot(history_dropout.epoch, history_dropout.history['accuracy'], label='dropout')
axs[1].plot(history_adl_init.epoch, history_adl_init.history['accuracy'], label='ADL from init')
axs[1].plot(history_adl_orig.epoch, history_adl_orig.history['accuracy'], label='ADL from orig')
axs[1].set_xlabel('epochs')
axs[1].set_ylabel('accuracy')
axs[1].legend()

plt.show()

# %%
# %%time

percentile = np.arange(100,0,-10)
res_perc = np.zeros((3,len(percentile)))

for i,p in enumerate(percentile):
    w1 = model.layers[1].w.numpy()
    w2 = model.layers[2].w.numpy()
    w3 = model.layers[3].w.numpy()
    w1[np.abs(w1) < np.percentile(np.abs(w1), p)] = 0
    w2[np.abs(w2) < np.percentile(np.abs(w2), p)] = 0
    w3[np.abs(w3) < np.percentile(np.abs(w3), p)] = 0
    pred = keras.activations.softmax(tf.convert_to_tensor(
        np.maximum(0, np.maximum(0, inputs @ w1) @ w2) @ w3))
    res_perc[0,i] = p
    res_perc[1,i] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, pred))
    res_perc[2,i] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, pred))

# %%
# %%time

k_ratios = [0.05, .1, .2, .5, 1, 2, 3, 4, 10]

res_perc_rand = np.zeros((3,len(k_ratios)))
w1 = model.layers[1].w.numpy()
w2 = model.layers[2].w.numpy()
w3 = model.layers[3].w.numpy()

for i,k in enumerate(k_ratios):
    k1 = int(w1.size * k)
    k2 = int(w2.size * k)
    k3 = int(w3.size * k)
    w1_r = random_sketch_vector(w1, k1)
    w2_r = random_sketch_vector(w2, k2)
    w3_r = random_sketch_vector(w3, k3)
    pred = keras.activations.softmax(tf.convert_to_tensor(
        np.maximum(0, np.maximum(0, inputs @ w1_r) @ w2_r) @ w3_r))
    res_perc_rand[0,i] = (np.sum(w1_r == 0) + np.sum(w2_r == 0) + np.sum(w3_r == 0)) \
                    * 100 / (w1.size + w2.size + w3.size)
    res_perc_rand[1,i] = tf.reduce_mean(keras.losses.sparse_categorical_crossentropy(y_train_mnist, pred))
    res_perc_rand[2,i] = tf.reduce_mean(keras.metrics.sparse_categorical_accuracy(y_train_mnist, pred))
# Out:
# Wall time: 2min 46s

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3), constrained_layout=True)
plt.subplot(1,2,1)
plt.plot(res_perc[0,:],res_perc[1,:],'*')
plt.plot(res_perc_rand[0,:],res_perc_rand[1,:],'^')
plt.legend(['naive prune', 'adl'])
plt.xlabel('percentage of zero elements')
plt.ylabel('loss')

plt.subplot(1,2,2)
plt.plot(res_perc[0,:],res_perc[2,:],'*')
plt.plot(res_perc_rand[0,:],res_perc_rand[2,:],'^')
plt.legend(['naive prune', 'adl'])
plt.xlabel('percentage of zero elements')
plt.ylabel('accuracy')

plt.show()
